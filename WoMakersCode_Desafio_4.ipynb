# %% [markdown]
# <a href="https://colab.research.google.com/github/Izanjos/Projects/blob/develop/WoMakersCode_Desafio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pydataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.9 MB 778 kB/s
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939432 sha256=5156dc5de69bf4c2419f66832b7bbf68ea19f89b809d6974056854946b14aadd
#   Stored in directory: /root/.cache/pip/wheels/d7/e5/36/85d319586b4a405d001029d489102f526ce5546248c295932a
# Successfully built pydataset
# ...

# %%
import pydataset
from pydataset import data
# Out:
# initiated datasets repo at: /root/.pydataset/

# %%
futebol = data("Bundesliga")
display(futebol)
# Out:
#                         HomeTeam              AwayTeam  HomeGoals  AwayGoals  \
# 1                  Werder Bremen     Borussia Dortmund          3          2
# 2              Hertha BSC Berlin       1. FC Nuernberg          1          1
# 3              Preussen Muenster          Hamburger SV          1          1
# 4            Eintracht Frankfurt  1. FC Kaiserslautern          1          1
# 5                  Karlsruher SC        Meidericher SV          1          4
# ...                          ...                   ...        ...        ...
# 14014          Arminia Bielefeld           Hannover 96          2          2
# 14015              Karlsruher SC     Hertha BSC Berlin          4          0
# 14016                1. FC Koeln            VfL Bochum          1          1
# 14017  Borussia Moenchengladbach     Borussia Dortmund          1          1
# 14018                 Schalke 04       1899 Hoffenheim          2          3
#
#        Round  Year                 Date
# ...

# %%
futebol.isnull().sum()
# Out:
# HomeTeam     0
# AwayTeam     0
# HomeGoals    0
# AwayGoals    0
# Round        0
# Year         0
# Date         2
# dtype: int64

# %%
futebol['TotalGoalsMethod1'] = futebol[['HomeGoals','AwayGoals']].sum(axis=1)
futebol['TotalGoalsMethod2'] = futebol[['HomeGoals', 'AwayGoals']].values.sum(axis=1)
futebol['TotalGoalsMethod3'] = futebol.iloc[:, 2:4].sum(axis=1)
display(futebol)
# Out:
#                         HomeTeam              AwayTeam  HomeGoals  AwayGoals  \
# 1                  Werder Bremen     Borussia Dortmund          3          2
# 2              Hertha BSC Berlin       1. FC Nuernberg          1          1
# 3              Preussen Muenster          Hamburger SV          1          1
# 4            Eintracht Frankfurt  1. FC Kaiserslautern          1          1
# 5                  Karlsruher SC        Meidericher SV          1          4
# ...                          ...                   ...        ...        ...
# 14014          Arminia Bielefeld           Hannover 96          2          2
# 14015              Karlsruher SC     Hertha BSC Berlin          4          0
# 14016                1. FC Koeln            VfL Bochum          1          1
# 14017  Borussia Moenchengladbach     Borussia Dortmund          1          1
# 14018                 Schalke 04       1899 Hoffenheim          2          3
#
# ...

# %%
futebol['TotalGoalsMethod1'].max()
# Out:
# 12

# %%
futebol['TotalGoalsMethod1'].idxmax()
# Out:
# 81

# %%
futebol.loc[futebol['TotalGoalsMethod1'].idxmax()]
# Out:
# HomeTeam                Borussia Dortmund
# AwayTeam             1. FC Kaiserslautern
# HomeGoals                               9
# AwayGoals                               3
# Round                                  11
# Year                                 1963
# Date                  1963-11-16 09:30:00
# TotalGoalsMethod1                      12
# TotalGoalsMethod2                      12
# TotalGoalsMethod3                      12
# Name: 81, dtype: object

# %%
#https://stackoverflow.com/questions/43772362/how-to-print-a-specific-row-of-a-pandas-dataframe
#https://www.learneasysteps.com/how-to-calculate-top-5-max-values-in-pandas/

futebol.loc[81:81]
# Out:
#              HomeTeam              AwayTeam  HomeGoals  AwayGoals  Round  \
# 81  Borussia Dortmund  1. FC Kaiserslautern          9          3     11
#
#     Year                 Date  TotalGoalsMethod1  TotalGoalsMethod2  \
# 81  1963  1963-11-16 09:30:00                 12                 12
#
#     TotalGoalsMethod3
# 81                 12

# %%
futebol['TotalGoalsMethod1'].nlargest(6)
# Out:
# 81      12
# 2456    12
# 4052    12
# 4457    12
# 5788    12
# 183     11
# Name: TotalGoalsMethod1, dtype: int64

# %%
futebol.iloc[[80,2455,4051,4456,5787]]
# Out:
#                        HomeTeam                AwayTeam  HomeGoals  AwayGoals  \
# 81            Borussia Dortmund    1. FC Kaiserslautern          9          3
# 2456            Bayern Muenchen       Borussia Dortmund         11          1
# 4052                1. FC Koeln  Tennis Borussia Berlin          8          4
# 4457  Borussia Moenchengladbach       Borussia Dortmund         12          0
# 5788          Borussia Dortmund       Arminia Bielefeld         11          1
#
#       Round  Year                 Date  TotalGoalsMethod1  TotalGoalsMethod2  \
# 81       11  1963  1963-11-16 09:30:00                 12                 12
# 2456     16  1971  1971-11-27 09:30:00                 12                 12
# 4052     23  1976  1977-02-26 09:30:00                 12                 12
# 4457     34  1977  1978-04-29 09:30:00                 12                 12
# 5788     12  1982  1982-11-06 09:30:00                 12                 12
#
#       TotalGoalsMethod3
# ...

# %%
#Data, Times participantes e Placar
futebol.loc[[81,2456,4052,4457,5788],['Date','HomeTeam','AwayTeam','HomeGoals','AwayGoals']]
# Out:
#                      Date                   HomeTeam                AwayTeam  \
# 81    1963-11-16 09:30:00          Borussia Dortmund    1. FC Kaiserslautern
# 2456  1971-11-27 09:30:00            Bayern Muenchen       Borussia Dortmund
# 4052  1977-02-26 09:30:00                1. FC Koeln  Tennis Borussia Berlin
# 4457  1978-04-29 09:30:00  Borussia Moenchengladbach       Borussia Dortmund
# 5788  1982-11-06 09:30:00          Borussia Dortmund       Arminia Bielefeld
#
#       HomeGoals  AwayGoals
# 81            9          3
# 2456         11          1
# 4052          8          4
# 4457         12          0
# 5788         11          1

# %%
teste = 1
print(teste)
